# %%
#regular expression
import re
import pandas as pd

# %%
f = open('WhatsApp Chat with Tarun Srm 2.txt','r',encoding = 'utf-8')

# %%
data = f.read()

# %%
#print(type(data)) ---> str
print(data)
# Out:
# 05/07/22, 12:12 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 02/07/22, 23:07 - Rikashikuariri: Waiting for this message
# 03/07/22, 19:04 - Rikashikuariri: Waiting for this message
# 02/07/22, 23:10 - Tarun Srm 2: Waiting for this message
# 03/07/22, 19:25 - Tarun Srm 2: Waiting for this message
# 04/07/22, 23:15 - Rikashikuariri: Waiting for this message
# 04/07/22, 23:59 - Rikashikuariri: Waiting for this message
# 05/07/22, 00:06 - Rikashikuariri: Waiting for this message
# 05/07/22, 00:12 - Rikashikuariri: Waiting for this message
# 05/07/22, 00:32 - Rikashikuariri: Waiting for this message
# 05/07/22, 12:12 - Tarun Srm 2: <Media omitted>
# 05/07/22, 12:12 - Tarun Srm 2: <Media omitted>
# 05/07/22, 12:12 - Tarun Srm 2: <Media omitted>
# 05/07/22, 12:12 - Tarun Srm 2: <Media omitted>
# 05/07/22, 12:12 - Tarun Srm 2: <Media omitted>
# 05/07/22, 12:12 - Tarun Srm 2: <Media omitted>
# ...

# %%
# website name - regex101.com
pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

# %%
#messages = re.split(pattern,data)
messages = re.split(pattern,data)[1:]
messages
# Out:
# ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'Rikashikuariri: Waiting for this message\n',
#  'Rikashikuariri: Waiting for this message\n',
#  'Tarun Srm 2: Waiting for this message\n',
#  'Tarun Srm 2: Waiting for this message\n',
#  'Rikashikuariri: Waiting for this message\n',
#  'Rikashikuariri: Waiting for this message\n',
#  'Rikashikuariri: Waiting for this message\n',
#  'Rikashikuariri: Waiting for this message\n',
#  'Rikashikuariri: Waiting for this message\n',
#  'Tarun Srm 2: <Media omitted>\n',
#  'Tarun Srm 2: <Media omitted>\n',
#  'Tarun Srm 2: <Media omitted>\n',
#  'Tarun Srm 2: <Media omitted>\n',
#  'Tarun Srm 2: <Media omitted>\n',
#  'Tarun Srm 2: <Media omitted>\n',
#  'Tarun Srm 2: <Media omitted>\n',
#  'Tarun Srm 2: <Media omitted>\n',
#  'Tarun Srm 2: <Media omitted>\n',
#  'Tarun Srm 2: 12 K solraan da\n',
#  'Tarun Srm 2: Waiting for this message\n',
# ...

# %%
dates = re.findall(pattern, data)
dates
# Out:
# ['05/07/22, 12:12 - ',
#  '02/07/22, 23:07 - ',
#  '03/07/22, 19:04 - ',
#  '02/07/22, 23:10 - ',
#  '03/07/22, 19:25 - ',
#  '04/07/22, 23:15 - ',
#  '04/07/22, 23:59 - ',
#  '05/07/22, 00:06 - ',
#  '05/07/22, 00:12 - ',
#  '05/07/22, 00:32 - ',
#  '05/07/22, 12:12 - ',
#  '05/07/22, 12:12 - ',
#  '05/07/22, 12:12 - ',
#  '05/07/22, 12:12 - ',
#  '05/07/22, 12:12 - ',
#  '05/07/22, 12:12 - ',
#  '05/07/22, 12:12 - ',
#  '05/07/22, 12:12 - ',
#  '05/07/22, 12:12 - ',
#  '05/07/22, 12:12 - ',
#  '04/07/22, 20:33 - ',
#  '04/07/22, 23:24 - ',
#  '05/07/22, 00:12 - ',
#  '05/07/22, 00:34 - ',
#  '05/07/22, 14:30 - ',
#  '05/07/22, 19:58 - ',
#  '05/07/22, 19:58 - ',
#  '05/07/22, 20:10 - ',
#  '05/07/22, 20:16 - ',
#  '05/07/22, 20:17 - ',
#  '05/07/22, 20:18 - ',
#  '05/07/22, 20:18 - ',
#  '05/07/22, 20:18 - ',
#  '05/07/22, 20:23 - ',
#  '05/07/22, 20:23 - ',
#  '05/07/22, 20:24 - ',
#  '05/07/22, 21:11 - ',
#  '05/07/22, 21:11 - ',
#  '05/07/22, 21:11 - ',
#  '06/07/22, 10:44 - ',
# ...

# %%
df = pd.DataFrame({'user_message':messages,'message_date':dates})
#converting message data type
df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%y, %H:%M - ')
df.rename(columns = {'message_date' : 'date'}, inplace = True)

df.head()
# Out:
#                                         user_message                date
# 0  Messages and calls are end-to-end encrypted. N... 2022-07-05 12:12:00
# 1         Rikashikuariri: Waiting for this message\n 2022-07-02 23:07:00
# 2         Rikashikuariri: Waiting for this message\n 2022-07-03 19:04:00
# 3            Tarun Srm 2: Waiting for this message\n 2022-07-02 23:10:00
# 4            Tarun Srm 2: Waiting for this message\n 2022-07-03 19:25:00

# %%
df.shape
# Out:
# (3039, 2)

# %%
#seperate users and message
users = []
messages = []
for message in df['user_message']:
    entry = re.split('([\w\W]+?):\s', message)
    if entry[1:]:  # user name
        users.append(entry[1])
        messages.append(" ".join(entry[2:]))
    else:
        users.append('group_notification')
        messages.append(entry[0])

df['user'] = users
df['message'] = messages
df.drop(columns=['user_message'], inplace=True)

df.head()
# Out:
#                  date                user  \
# 0 2022-07-05 12:12:00  group_notification
# 1 2022-07-02 23:07:00      Rikashikuariri
# 2 2022-07-03 19:04:00      Rikashikuariri
# 3 2022-07-02 23:10:00         Tarun Srm 2
# 4 2022-07-03 19:25:00         Tarun Srm 2
#
#                                              message
# 0  Messages and calls are end-to-end encrypted. N...
# 1                         Waiting for this message\n
# 2                         Waiting for this message\n
# 3                         Waiting for this message\n
# 4                         Waiting for this message\n

# %%
# extracting date,month name,year,hour,minute
df['only_date'] = df['date'].dt.date
df['year'] = df['date'].dt.year
df['month_num'] = df['date'].dt.month
df['month'] = df['date'].dt.month_name()
df['day'] = df['date'].dt.day
df['day_name'] = df['date'].dt.day_name()
df['hour'] = df['date'].dt.hour
df['minute'] = df['date'].dt.minute

# %%
df.head()
# Out:
#                  date                user  \
# 0 2022-07-05 12:12:00  group_notification
# 1 2022-07-02 23:07:00      Rikashikuariri
# 2 2022-07-03 19:04:00      Rikashikuariri
# 3 2022-07-02 23:10:00         Tarun Srm 2
# 4 2022-07-03 19:25:00         Tarun Srm 2
#
#                                              message   only_date  year  \
# 0  Messages and calls are end-to-end encrypted. N...  2022-07-05  2022
# 1                         Waiting for this message\n  2022-07-02  2022
# 2                         Waiting for this message\n  2022-07-03  2022
# 3                         Waiting for this message\n  2022-07-02  2022
# 4                         Waiting for this message\n  2022-07-03  2022
#
#    month_num month  day  day_name  hour  minute
# 0          7  July    5   Tuesday    12      12
# 1          7  July    2  Saturday    23       7
# 2          7  July    3    Sunday    19       4
# 3          7  July    2  Saturday    23      10
# ...

# %%
df[df['user'] == 'Tarun Srm 2']
# Out:
#                     date         user                     message   only_date  \
# 3    2022-07-02 23:10:00  Tarun Srm 2  Waiting for this message\n  2022-07-02
# 4    2022-07-03 19:25:00  Tarun Srm 2  Waiting for this message\n  2022-07-03
# 10   2022-07-05 12:12:00  Tarun Srm 2           <Media omitted>\n  2022-07-05
# 11   2022-07-05 12:12:00  Tarun Srm 2           <Media omitted>\n  2022-07-05
# 12   2022-07-05 12:12:00  Tarun Srm 2           <Media omitted>\n  2022-07-05
# ...                  ...          ...                         ...         ...
# 3030 2022-09-25 17:19:00  Tarun Srm 2                        No\n  2022-09-25
# 3032 2022-09-25 22:29:00  Tarun Srm 2               Match paaru\n  2022-09-25
# 3033 2022-09-25 22:29:00  Tarun Srm 2            moratta irukku\n  2022-09-25
# 3037 2022-09-25 22:35:00  Tarun Srm 2                       Won\n  2022-09-25
# 3038 2022-09-25 22:36:00  Tarun Srm 2                       Bus\n  2022-09-25
#
# ...

# %%
df[df['user'] == 'Tarun Srm 2'].shape
# Out:
# (1835, 11)

# %%
words = []
for message in df['message']:
    words.extend(message.split())

# %%
len(words)
# Out:
# 11558

# %%
pip install urlextract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#to get url alone from string
from urlextract import URLExtract

extractor = URLExtract()
urls = extractor.find_urls("Lets's www.gmail.com have URL stackoverflow.com as an example google.com, http://facebook.com, ftp://url.in")
urls
# Out:
# ['www.gmail.com',
#  'stackoverflow.com',
#  'google.com',
#  'http://facebook.com',
#  'ftp://url.in']

# %%
links = []
for message in df['message']:
    links.extend(extractor.find_urls(message))

# %%
len(links)
# Out:
# 251

# %%
x = df['user'].value_counts().head()

# %%
import matplotlib.pyplot as plt
name = x.index
count = x.values

# %%
plt.bar(name,count)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(name,count)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
round((df['user'].value_counts()/df.shape[0])*100,2).reset_index().rename(columns={'index':'name','user':'percent'})
# Out:
#                  name  percent
# 0         Tarun Srm 2    60.38
# 1      Rikashikuariri    39.59
# 2  group_notification     0.03

# %%
words = []
for message in df['message']:
    words.extend(message.split())

# %%
words
# Out:
# ['Messages',
#  'and',
#  'calls',
#  'are',
#  'end-to-end',
#  'encrypted.',
#  'No',
#  'one',
#  'outside',
#  'of',
#  'this',
#  'chat,',
#  'not',
#  'even',
#  'WhatsApp,',
#  'can',
#  'read',
#  'or',
#  'listen',
#  'to',
#  'them.',
#  'Tap',
#  'to',
#  'learn',
#  'more.',
#  'Waiting',
#  'for',
#  'this',
#  'message',
#  'Waiting',
#  'for',
#  'this',
#  'message',
#  'Waiting',
#  'for',
#  'this',
#  'message',
#  'Waiting',
#  'for',
#  'this',
#  'message',
#  'Waiting',
#  'for',
#  'this',
#  'message',
#  'Waiting',
#  'for',
#  'this',
#  'message',
#  'Waiting',
#  'for',
#  'this',
#  'message',
#  'Waiting',
#  'for',
#  'this',
#  'message',
#  'Waiting',
#  'for',
#  'this',
#  'message',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '12',
#  'K',
# ...

# %%
from collections import Counter
#Counter(words).most_common(20)
pd.DataFrame(Counter(words).most_common(20))
# Out:
#            0    1
# 0     <Media  668
# 1   omitted>  668
# 2         da  151
# 3          =  141
# 4         Ok  102
# 5        and   87
# 6         la   83
# 7         nu   77
# 8        Dei   77
# 9        for   73
# 10        ok   70
# 11        to   62
# 12        ah   62
# 13        ku   60
# 14       the   52
# 15         }   47
# 16        in   43
# 17       int   42
# 18      test   41
# 19         i   37

# %%
#remove group notification
temp = df[df['user'] != 'group_notification']
#remove media ommited
temp = temp[temp['message'] != '<Media Omitted>\n']

# %%
#remove stop words
f = open('hinglish.txt','r')
stop_words = f.read()

# %%
words = []
for message in temp['message']:
    for word in message.lower().split():
        if word not in stop_words:
            words.append(word)

# %%
from collections import Counter
#Counter(words).most_common(20)
pd.DataFrame(Counter(words).most_common(20))
# Out:
#            0    1
# 0     <media  668
# 1   omitted>  668
# 2          =  141
# 3        dei  111
# 4         nu   78
# 5       enna   59
# 6          }   47
# 7       test   46
# 8       illa   34
# 9      dhaan   34
# 10      code   33
# 11   message   28
# 12    coding   28
# 13       ohh   27
# 14    string   25
# 15      pola   24
# 16    return   23
# 17        0;   23
# 18     panna   23
# 19       oru   22

# %%
pip install emoji
# Out:
# ...
#   Created wheel for emoji: filename=emoji-2.1.0-py3-none-any.whl size=212392 sha256=f91ddacc9e12d32c7e932303589090ec37687f1ca20a15de3404d0b9b642a564
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\b0\4a\c8\9c580a0ea94dea641b8023456a1b178a7e4509d992224ed4aa
# Successfully built emoji
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import emoji

# %%
emojis = []
for message in df['message']:
    emojis.extend([c for c in message if c in emoji.EMOJI_DATA])

# %%
emoji_df = pd.DataFrame(Counter(emojis).most_common(len(Counter(emojis))))
emoji_df
# Out:
#     0   1
# 0   😂  32
# 1   👍   8
# 2   😭   7
# 3   🌯   6
# 4   🙂   6
# 5   😢   5
# 6   🥲   4
# 7   🍼   4
# 8   🔥   3
# 9   🤝   2
# 10  🤡   2
# 11  😴   2
# 12  🤧   2
# 13  💐   2
# 14  👎   1
# 15  ✈   1
# 16  😅   1
# 17  🍺   1
# 18  ☕   1
# 19  😶   1
# 20  ✌   1
# 21  👌   1
# 22  🏻   1
# 23  🤗   1
# 24  👑   1
# 25  🤌   1
# 26  💩   1
# 27  ✊   1
# 28  💦   1
# 29  ☺   1
# 30  🫣   1
# 31  😳   1

# %%
plt.bar(emoji_df[0].head(),emoji_df[1].head())
# Out:
# <BarContainer object of 5 artists>
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127791 (\N{BURRITO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128578 (\N{SLIGHTLY SMILING FACE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df['month_num'] = df['date'].dt.month

# %%
timeline = df.groupby(['year','month_num','month']).count()['message'].reset_index()

# %%
timeline
# Out:
#    year  month_num      month  message
# 0  2022          7       July      740
# 1  2022          8     August     1384
# 2  2022          9  September      915

# %%
time = []
for i in range(timeline.shape[0]):
    time.append(timeline['month'][i] + "-" + str(timeline['year'][i]))

# %%
timeline['time'] = time

# %%
timeline
# Out:
#    year  month_num      month  message            time
# 0  2022          7       July      740       July-2022
# 1  2022          8     August     1384     August-2022
# 2  2022          9  September      915  September-2022

# %%
plt.plot(timeline['time'],timeline['message'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df['only_date'] = df['date'].dt.date

# %%
daily_timeline = df.groupby('only_date').count()['message'].reset_index()
daily_timeline
# Out:
#      only_date  message
# 0   2022-07-02        2
# 1   2022-07-03        2
# 2   2022-07-04        4
# 3   2022-07-05       31
# 4   2022-07-06        6
# ..         ...      ...
# 80  2022-09-21       45
# 81  2022-09-22       99
# 82  2022-09-23       85
# 83  2022-09-24       20
# 84  2022-09-25      123
#
# [85 rows x 2 columns]

# %%
plt.figure(figsize =(18,10))
plt.plot(daily_timeline['only_date'],daily_timeline['message'])

# %%
df['day_name'] = df['date'].dt.day_name()

# %%
df['day_name'].value_counts()
# Out:
# Thursday     770
# Sunday       517
# Wednesday    462
# Saturday     406
# Friday       376
# Monday       280
# Tuesday      228
# Name: day_name, dtype: int64

# %%
period = []
for hour in df[['day_name','hour']]['hour']:
    if hour == 23:
        period.append(str(hour) + "-" + str('00'))
    elif hour == 0:
        period.append(str('00') + "-" + str(hour+1))
    else:
        period.append(str(hour) + "-" + str(hour+1))

# %%
df['period'] = period

# %%
df.sample(5)
# Out:
#                     date            user  \
# 1949 2022-08-27 20:12:00  Rikashikuariri
# 2131 2022-09-01 15:39:00  Rikashikuariri
# 967  2022-08-06 17:07:00  Rikashikuariri
# 1782 2022-08-20 18:47:00  Rikashikuariri
# 881  2022-08-05 15:32:00  Rikashikuariri
#
#                                          message   only_date  year  month_num  \
# 1949                                       Yes\n  2022-08-27  2022          8
# 2131                                        Ok\n  2022-09-01  2022          9
# 967   5 30 lendhu dhan atti dance poda mudiyum\n  2022-08-06  2022          8
# 1782                            Dei nane potrn\n  2022-08-20  2022          8
# 881                                        Aam\n  2022-08-05  2022          8
#
#           month  day  day_name  hour  minute period
# 1949     August   27  Saturday    20      12  20-21
# 2131  September    1  Thursday    15      39  15-16
# 967      August    6  Saturday    17       7  17-18
# ...

# %%
import seaborn as sns
plt.figure(figsize=(20,6))
sns.heatmap(df.pivot_table(index='day_name',columns='period',values='message',aggfunc='count').fillna(0))
plt.yticks(rotation='horizontal')
plt.show()

# %%
df.pivot_table(index='day_name',columns='period',values='message',aggfunc='count').fillna(0)
# Out:
# period     00-1  1-2  10-11  11-12  12-13  13-14  14-15  15-16  16-17  17-18  \
# day_name
# Friday      3.0  1.0    0.0    1.0   30.0   33.0   22.0   45.0   45.0   10.0
# Monday      9.0  3.0    6.0   22.0   31.0   23.0   41.0    0.0   10.0    9.0
# Saturday    7.0  1.0   16.0   21.0   11.0   54.0   31.0   49.0    8.0   51.0
# Sunday     11.0  6.0   57.0   24.0   14.0    9.0   22.0   30.0   61.0  105.0
# Thursday    0.0  0.0    8.0    8.0   16.0    5.0   14.0   38.0   78.0   99.0
# Tuesday     5.0  3.0    8.0   88.0   28.0   16.0   21.0    7.0    5.0    3.0
# Wednesday  12.0  2.0   14.0   31.0    5.0   42.0   17.0  110.0  108.0   44.0
#
# period     ...  20-21  21-22  22-23  23-00  4-5  5-6  6-7  7-8   8-9  9-10
# day_name   ...
# Friday     ...   13.0    2.0    7.0   12.0  0.0  0.0  0.0  6.0   5.0   6.0
# Monday     ...    8.0   13.0    7.0   10.0  0.0  0.0  1.0  0.0   2.0  25.0
# Saturday   ...    8.0   23.0   18.0   12.0  0.0  0.0  0.0  2.0  14.0   7.0
# ...
